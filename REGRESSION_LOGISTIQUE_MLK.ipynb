# %% [markdown]
# # REGRESSION LOGISTIQUE

# %%
df_class = pd.read_csv('Co2_final.csv', header=0)

display(df_class.head())
# Out:
#          Mp         T  Ct  m (kg)  Ewltp (g/km)  W (mm)  At1 (mm)      Ft Fm  \
# 0  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 1  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 2  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 3  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 4  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
#
#    ec (cm3)  ep (KW)  Fuel consumption
# 0     999.0     48.0                5.2
# 1     999.0     48.0                5.2
# 2     999.0     48.0                5.2
# 3     999.0     48.0                5.2
# 4     999.0     48.0                5.2

# %%
df_class.info()

# %%
# Calcul de la mediane 
Mediane_y = df_class['Ewltp (g/km)'].median()

# %%
# Création de la veriable variable cible
df_class['Pollution_labels'] = (df_class['Ewltp (g/km)'] > Mediane_y).astype(int)

# %%
df_class.head()
# Out:
#          Mp         T  Ct  m (kg)  Ewltp (g/km)  W (mm)  At1 (mm)      Ft Fm  \
# 0  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 1  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 2  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 3  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
# 4  0.148938  0.003688  M1   993.0         117.0  2492.0    1455.0  petrol  M
#
#    ec (cm3)  ep (KW)  Fuel consumption   Pollution_labels
# 0     999.0     48.0                5.2                 0
# 1     999.0     48.0                5.2                 0
# 2     999.0     48.0                5.2                 0
# 3     999.0     48.0                5.2                 0
# 4     999.0     48.0                5.2                 0

# %% [markdown]
# # Qualité des données

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3498786 entries, 0 to 3498785
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Mp                 float64
#  1   T                  float64
#  2   Ct                 object
#  3   m (kg)             float64
#  4   Ewltp (g/km)       float64
#  5   W (mm)             float64
#  6   At1 (mm)           float64
#  7   Ft                 object
#  8   Fm                 object
#  9   ec (cm3)           float64
#  10  ep (KW)            float64
#  11  Fuel consumption   float64
#  12  Pollution_labels   int32
# dtypes: float64(9), int32(1), object(3)
# memory usage: 333.7+ MB

# %%
df_class.describe(include="all")
# Out:
#                   Mp             T       Ct        m (kg)  Ewltp (g/km)  \
# count   3.498786e+06  3.498786e+06  3498786  3.498786e+06  3.498786e+06
# unique           NaN           NaN        4           NaN           NaN
# top              NaN           NaN       M1           NaN           NaN
# freq             NaN           NaN  3327296           NaN           NaN
# mean    1.680257e-01  1.434661e-02      NaN  1.505278e+03  1.251754e+02
# std     9.599866e-02  1.607522e-02      NaN  3.251205e+02  4.701375e+01
# min     9.524381e-03  2.839330e-07      NaN  9.150000e+02  1.200000e+01
# 25%     7.469239e-02  4.975357e-03      NaN  1.263000e+03  1.150000e+02
# 50%     1.489384e-01  8.129001e-03      NaN  1.451000e+03  1.280000e+02
# 75%     2.938415e-01  1.787472e-02      NaN  1.701000e+03  1.450000e+02
# max     2.938415e-01  6.637359e-02      NaN  4.255000e+03  4.560000e+02
#
#               W (mm)      At1 (mm)       Ft       Fm      ec (cm3)  \
# ...

# %%
df_class.isnull().sum()
# Out:
# Mp                   0
# T                    0
# Ct                   0
# m (kg)               0
# Ewltp (g/km)         0
# W (mm)               0
# At1 (mm)             0
# Ft                   0
# Fm                   0
# ec (cm3)             0
# ep (KW)              0
# Fuel consumption     0
# Pollution_labels     0
# dtype: int64

# %% [markdown]
# # Descripition de la base de données

# %%
# Séparation des données et des cibles 
df_class_new = df_class.drop(['Pollution_labels', 'Ewltp (g/km)'], axis=1)
print(df_class_new.head())
# Out:
#          Mp         T  Ct  m (kg)  W (mm)  At1 (mm)      Ft Fm  ec (cm3)  \
# 0  0.148938  0.003688  M1   993.0  2492.0    1455.0  petrol  M     999.0
# 1  0.148938  0.003688  M1   993.0  2492.0    1455.0  petrol  M     999.0
# 2  0.148938  0.003688  M1   993.0  2492.0    1455.0  petrol  M     999.0
# 3  0.148938  0.003688  M1   993.0  2492.0    1455.0  petrol  M     999.0
# 4  0.148938  0.003688  M1   993.0  2492.0    1455.0  petrol  M     999.0
#
#    ep (KW)  Fuel consumption
# 0     48.0                5.2
# 1     48.0                5.2
# 2     48.0                5.2
# 3     48.0                5.2
# 4     48.0                5.2

# %%
# Sélectionner les variables catégorielles
cat_vars = ['Ct', 'Ft', 'Fm', 'Pollution_labels']


# Générer un pie plot pour chaque variable catégorielle
for var in cat_vars:
    df_class[var].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title(var)
    plt.axis('equal')
    plt.show()

# %%
# Générer un bar plot pour chaque variable catégorielle
for var in cat_vars:
    df_class[var].value_counts().plot(kind='bar')
    plt.title(var)
    plt.xlabel('Modalités')
    plt.ylabel('Fréquence')
    plt.show()

# %%
# Sélectionner les variables numériques
num_vars = df_class.drop(cat_vars, axis=1)
# Générer un box plot pour chaque variable numérique
for var in num_vars:
    df_class[var].plot(kind='box')
    plt.title(var)
    plt.show()

# %% [markdown]
# # Analyses bivariée

# %%
import seaborn as sns
# Sélectionner les variables catégorielles hors variable cible.
cat_vars = ['Ct', 'Ft', 'Fm']

# Générer un count plot pour chaque variable catégorielle
# Définir la taille des figures

# Générer un bar plot pour chaque variable catégorielle
for var in cat_vars:
    figsize = (20, 20)
    (df_class.groupby([var, 'Pollution_labels'])['Pollution_labels'].count()/df_class.groupby([var])[var].count()).unstack(level=1).plot(kind='bar', stacked=True)
    plt.title(var)
    plt.xlabel('Modalités')
    plt.ylabel('Proportion (%)')
    plt.legend(['Faible', 'Forte'])
    plt.show()

# %%
from scipy.stats import chi2_contingency
# Sélectionner les variables catégorielles
cat_vars = ['Ct', 'Ft', 'Fm']

# Initialiser les listes pour stocker les résultats
var_names = []
chi2_stats = []
p_values = []
cramer_vs = []

# Parcourir toutes les variables catégorielles
for var in cat_vars:
    # Calculer le tableau de contingence
    contingency_table = pd.crosstab(df_class['Pollution_labels'], df_class[var])
    # Calculer la statistique de test du Chi-deux et la p-valeur
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    # Calculer le coefficient V de Cramer
    n = contingency_table.sum().sum()
    phi2 = chi2/n
    r,k = contingency_table.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rc = r-((r-1)**2)/(n-1)
    kc = k-((k-1)**2)/(n-1)
    cramer_v = np.sqrt(phi2corr/min(rc-1,kc-1))
    # Ajouter les résultats aux listes correspondantes
    var_names.append(var)
    chi2_stats.append(chi2)
    p_values.append(p)
    cramer_vs.append(cramer_v)

# Créer un DataFrame avec les résultats
results_df = pd.DataFrame({
    'Variable': var_names,
    'Chi2': chi2_stats,
    'P-valeur': p_values,
    'V de Cramer': cramer_vs
})

# Trier le DataFrame par ordre croissant de V de Cramer
results_df.sort_values(by='V de Cramer', inplace=True,ascending=False)

# Afficher le tableau des résultats
print(results_df)
# Out:
#   Variable           Chi2  P-valeur  V de Cramer
# 1       Ft  707206.834488       0.0     0.449586
# 2       Fm  658453.722354       0.0     0.433813
# 0       Ct   15566.974859       0.0     0.066696

# %%
# Générer un box plot pour chaque variable numérique
for var in num_vars:
    sns.boxplot(x='Pollution_labels', y=var, data=df_class)
    plt.title(var)
    plt.xlabel('Reponse binaire')
    plt.ylabel('Valeur')
    plt.show()

# %%
import scipy.stats as stats
# Initialiser les listes pour stocker les résultats
var_names = []
kw_stats = []
p_values = []

# Parcourir toutes les variables numériques
for var in num_vars:
    # Calculer les groupes de valeurs
    groups = [df_class[df_class['Pollution_labels'] == 0][var], df_class[df_class['Pollution_labels'] == 1][var]]
    # Appliquer le test de Kruskal-Wallis
    kw_stat, p = stats.kruskal(*groups)
    # Ajouter les résultats aux listes correspondantes
    var_names.append(var)
    kw_stats.append(kw_stat)
    p_values.append(p)

# Créer un DataFrame avec les résultats
results_df = pd.DataFrame({
    'Variable': var_names,
    'Kruskal-Wallis': kw_stats,
    'P-valeur': p_values
})

# Trier le DataFrame par ordre croissant de p-valeur
results_df.sort_values(by='P-valeur', inplace=True)

# Afficher le tableau des résultats
print(results_df)
# Out:
#             Variable  Kruskal-Wallis  P-valeur
# 0                 Mp    6.610886e+04       0.0
# 1                  T    1.548838e+05       0.0
# 2             m (kg)    2.991848e+05       0.0
# 3       Ewltp (g/km)    2.624170e+06       0.0
# 4             W (mm)    3.655269e+05       0.0
# 5           At1 (mm)    4.018998e+05       0.0
# 6           ec (cm3)    2.575756e+05       0.0
# 7            ep (KW)    7.338945e+05       0.0
# 8  Fuel consumption     1.887873e+06       0.0

# %% [markdown]
# # Modélisation

# %% [markdown]
# #### Mettre à l'échelle des différentes valeurs

# %%
# Variables catégorielles disponibles dans le df
variables_categorielles = ['Ct', 'Ft', 'Fm']

# Effectuer le one-hot encoding
df_classi = pd.get_dummies(df_class, columns=variables_categorielles)

# Afficher les premières lignes du dataframe pour vérifier
display(df_classi.head())
# Out:
#          Mp         T  m (kg)  Ewltp (g/km)  W (mm)  At1 (mm)  ec (cm3)  \
# 0  0.148938  0.003688   993.0         117.0  2492.0    1455.0     999.0
# 1  0.148938  0.003688   993.0         117.0  2492.0    1455.0     999.0
# 2  0.148938  0.003688   993.0         117.0  2492.0    1455.0     999.0
# 3  0.148938  0.003688   993.0         117.0  2492.0    1455.0     999.0
# 4  0.148938  0.003688   993.0         117.0  2492.0    1455.0     999.0
#
#    ep (KW)  Fuel consumption   Pollution_labels  ...  Ft_e85  Ft_lpg  Ft_ng  \
# 0     48.0                5.2                 0  ...       0       0      0
# 1     48.0                5.2                 0  ...       0       0      0
# 2     48.0                5.2                 0  ...       0       0      0
# 3     48.0                5.2                 0  ...       0       0      0
# 4     48.0                5.2                 0  ...       0       0      0
#
#    Ft_petrol  Ft_petrol/electric  Fm_B  Fm_F  Fm_H  Fm_M  Fm_P
# ...

# %%
df_classi['Ewltp (g/km)'].describe()
# Out:
# count    3.498786e+06
# mean     1.251754e+02
# std      4.701375e+01
# min      1.200000e+01
# 25%      1.150000e+02
# 50%      1.280000e+02
# 75%      1.450000e+02
# max      4.560000e+02
# Name: Ewltp (g/km), dtype: float64

# %%
# Séparation des données et des cibles 
data = df_classi.drop(['Pollution_labels', 'Ewltp (g/km)'], axis=1)
print(data.head())
target = df_classi['Pollution_labels']
target.head()
# Out:
#          Mp         T  m (kg)  W (mm)  At1 (mm)  ec (cm3)  ep (KW)  \
# 0  0.148938  0.003688   993.0  2492.0    1455.0     999.0     48.0
# 1  0.148938  0.003688   993.0  2492.0    1455.0     999.0     48.0
# 2  0.148938  0.003688   993.0  2492.0    1455.0     999.0     48.0
# 3  0.148938  0.003688   993.0  2492.0    1455.0     999.0     48.0
# 4  0.148938  0.003688   993.0  2492.0    1455.0     999.0     48.0
#
#    Fuel consumption   Ct_M1  Ct_M1G  ...  Ft_e85  Ft_lpg  Ft_ng  Ft_petrol  \
# 0                5.2      1       0  ...       0       0      0          1
# 1                5.2      1       0  ...       0       0      0          1
# 2                5.2      1       0  ...       0       0      0          1
# 3                5.2      1       0  ...       0       0      0          1
# 4                5.2      1       0  ...       0       0      0          1
#
#    Ft_petrol/electric  Fm_B  Fm_F  Fm_H  Fm_M  Fm_P
# 0                   0     0     0     0     1     0
# ...

# %%
X = data
y = target
# Division des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=66)

# Afficher les résultats
print("X_train:\n", X_train)
print("X_test:\n", X_test)
print("y_train:\n", y_train)
print("y_test:\n", y_test)
# Out:
# X_train:
#                 Mp         T  m (kg)  W (mm)  At1 (mm)  ec (cm3)  ep (KW)  \
# 160362   0.293841  0.012308  1365.0  2624.0    1526.0    1498.0    110.0
# 948999   0.079177  0.005155  2510.0  2975.0    1678.0    2998.0    210.0
# 1385514  0.074692  0.000532  1615.0  2640.0    1550.0    1987.0    112.0
# 2115801  0.148938  0.014699  1321.0  2673.0    1563.0    1332.0     96.0
# 2542750  0.193783  0.021777  1055.0  2539.0    1483.0    1199.0     61.0
# ...           ...       ...     ...     ...       ...       ...      ...
# 3331930  0.079177  0.002713  1580.0  2851.0    1573.0    1998.0    190.0
# 1709135  0.293841  0.030210  1555.0  2628.0    1514.0    1984.0    245.0
# 1635450  0.293841  0.011681  1599.0  2786.0    1564.0    1968.0    110.0
# 1187891  0.293841  0.007450  1242.0  2554.0    1523.0     999.0     81.0
# 385852   0.074540  0.009836  1365.0  2729.0    1569.0    1332.0    100.0
#
#          Fuel consumption   Ct_M1  Ct_M1G  ...  Ft_e85  Ft_lpg  Ft_ng  \
# ...

# %%
# Créer et entraîner le classifieur LogisticRegression
clf = LogisticRegression(C=1.0, random_state=66)
clf.fit(X_train, y_train)

# Afficher les résultats de l'entraînement
print("Coefficient de régression :\n", clf.coef_)
print("Intercept de régression :\n", clf.intercept_)
print("Score de l'entraînement : {:.2f}".format(clf.score(X_train, y_train)))
print("Score du test : {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Coefficient de régression :
#  [[ 1.69195060e-01 -3.93657202e-02  1.47619941e-02 -8.69133221e-03
#   -1.58147634e-02 -2.53560915e-03  5.59999344e-02  4.05671436e+00
#    1.90516788e-01 -2.68127279e-01  3.52648150e-05  3.57891423e-06
#    1.87787394e+00 -4.00563590e-02 -2.64256793e-01 -1.25709244e+00
#   -3.14844675e-02  5.60821259e-01 -9.23376797e-01 -1.25715282e+00
#   -6.15886024e-02 -7.52906251e-01  2.95750918e+00 -9.63433156e-01]]
# Intercept de régression :
# ...

# %%
# Prédire les données de l'ensemble de test
y_pred = clf.predict(X_test)

# Afficher les prédictions
print("Prédictions pour l'ensemble de test :\n", y_pred)

from sklearn.metrics import confusion_matrix
# Créer et afficher la matrice de confusion
cm = confusion_matrix(y_test, y_pred)
print("Matrice de confusion :\n", cm)
# Out:
# Prédictions pour l'ensemble de test :
#  [0 0 1 ... 0 1 0]
# Matrice de confusion :
#  [[319884  34448]
#  [ 29325 316101]]

# %%
from sklearn.metrics import classification_report

# Générer et afficher le rapport de classification
classification_rep = classification_report(y_test, y_pred)
print("Rapport de classification :\n", classification_rep)
# Out:
# Rapport de classification :
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91    354332
#            1       0.90      0.92      0.91    345426
#
#     accuracy                           0.91    699758
#    macro avg       0.91      0.91      0.91    699758
# weighted avg       0.91      0.91      0.91    699758

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Calculer le taux de bonnes prédictions (accuracy) en utilisant la méthode `score`
accuracy = clf.score(X_test, y_test)
print("Taux de bonnes prédictions (accuracy) avec la méthode `score` : {:.2f}".format(accuracy))
# Out:
# Taux de bonnes prédictions (accuracy) avec la méthode `score` : 0.91

# %%
# Obtenir les probabilités pour les individus de X_test d'appartenir à la classe 0 ou la classe 1
probs = clf.predict_proba(X_test)

# Afficher le tableau des probabilités
probs_df = pd.DataFrame(probs, columns=['Probabilité classe 0', 'Probabilité classe 1'])
print("Tableau des probabilités :\n", probs_df)


# Créer un vecteur y_preds basé sur la probabilité d'appartenir à la classe 1 étant supérieure à 0.4
y_preds = (probs[:, 1] > 0.4).astype(int)
print("Vecteur des prédictions (y_preds) :\n", y_preds)

# Créer et afficher la matrice de confusion
cm = confusion_matrix(y_test, y_pred)
print("Matrice de confusion :\n", cm)
# Out:
# Tableau des probabilités :
#          Probabilité classe 0  Probabilité classe 1
# 0               8.842575e-01              0.115742
# 1               9.999256e-01              0.000074
# 2               1.446177e-08              1.000000
# 3               9.914286e-01              0.008571
# 4               2.425625e-05              0.999976
# ...                      ...                   ...
# 699753          4.532994e-04              0.999547
# 699754          2.092493e-01              0.790751
# 699755          9.978988e-01              0.002101
# 699756          2.359697e-02              0.976403
# 699757          9.979892e-01              0.002011
#
# [699758 rows x 2 columns]
# Vecteur des prédictions (y_preds) :
#  [0 0 1 ... 0 1 0]
# Matrice de confusion :
#  [[319884  34448]
#  [ 29325 316101]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_curve, auc

# Calculer les valeurs fpr (False Positive Rate), tpr (True Positive Rate) et les seuils
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1], pos_label=1)

# Afficher les valeurs fpr, tpr et seuils
print("False Positive Rate (FPR) :\n", fpr)
print("True Positive Rate (TPR) :\n", tpr)
print("Seuils :\n", thresholds)

# Calculer l'AUC
roc_auc = auc(fpr, tpr)
print("AUC : {:.2f}".format(roc_auc))

# Afficher les valeurs fpr, tpr et seuils
print("False Positive Rate (FPR) :\n", fpr)
print("True Positive Rate (TPR) :\n", tpr)
print("Seuils :\n", thresholds)
# Out:
# False Positive Rate (FPR) :
#  [0.         0.         0.         ... 0.99797647 0.99882032 1.        ]
# True Positive Rate (TPR) :
#  [0.         0.02082935 0.02269372 ... 1.         1.         1.        ]
# Seuils :
#  [2.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.88348394e-10
#  1.25539691e-10 8.36758611e-11]
# AUC : 0.98
# False Positive Rate (FPR) :
#  [0.         0.         0.         ... 0.99797647 0.99882032 1.        ]
# True Positive Rate (TPR) :
#  [0.         0.02082935 0.02269372 ... 1.         1.         1.        ]
# Seuils :
#  [2.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.88348394e-10
#  1.25539691e-10 8.36758611e-11]

# %%
# k) Tracer la courbe ROC
import matplotlib.pyplot as plt
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Modèle Clf (AUC = %0.98)')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Aléatoire (AUC = %0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de Faux Positifs')
plt.ylabel('Taux de Vrais Positifs')
plt.title('Courbe ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Interprtabilité des modèles
# ## II - Interpretabilité locale
# L'interprétabilité locale des modèles consite en un ensemble de techniques destinées à répondre à des questions telles ques :
# - Pourquoi le modèle a -t- il fait cette prédiction ?
# - Quel a été l'impact de cette valeur de caracterisique spécifique sur la prédiction?

# %% [markdown]
# ## II - 1 LIME

# %% [markdown]
# LIME est une technique qui permet un modèle simple autour de la prédiction que nous voulons expliquer et utilise ce modèle
# simple pour donner une explication . LIME peut être utilisé avec n'importe modèle de machine learning, pas seulement avec
# des arbres de décision ou de forêts aléatoires.
#
# L'idée de base de LIME est assez simple. Pour une  prédiction observée, LIME perturbe les entrées de la prédiction et essaie
# de comprendre comment ces perturbations affectent la sortie du modèle. Les attributs qui affectent le plus la sortie lorqu'ils
# sont considérés comme ayant une importance élévée pour cette prédiction spécifique.

# %%
# pip install lime --user

# %%
# import sys
# print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
# conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\ProgramData\Anaconda3
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# conda activate base
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import lime
from lime.lime_tabular import LimeTabularExplainer

# %%
# Création de l'explainer
explainer = LimeTabularExplainer(X_train.values,
                                 feature_names=X_train.columns.tolist(),
                                 class_names=[0, 1],
                                 mode='classification')

# %%
# Choix d'une exemple spécificque à expliquer
i = X_test.iloc[6].values

exp = explainer.explain_instance(i, clf.predict_proba)

# Afficher l'explication
exp.show_in_notebook(show_table=True)

# %% [markdown]
# ## II - Shapley Value
#
# La valeur du shapley , dans le contexte de l'interprétabilité de modèles d'apprentissage automatique, permet d'évaluer
# l'impact de chaque caractéristique sur une prédition donnée
# Elle fait cela en calculant la constribution moyenne de chaque caractéristique à la prédiction sur toutes les combinaisons
# possibles de caractéristiques

# %%
# pip install shap

# %%
import shap

# Créer un explainer SHAP pour le modèle de régression logistique 
explainer = shap.LinearExplainer(clf, X_train)

# Calcul des valeurs SHAP pour les instances de test
shap_values = explainer.shap_values(X_test)

# Visualiser les valeurs de Shapley pour une prédiction individuelle
shap.initjs() 
shap.force_plot(explainer.expected_value, shap_values[6], X_test.iloc[6])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# # Interprétabilité globale
#
# ## Importance des caractéristiques (Features importance)

# %%
# Extraire les coefficients absolus du modèle
importance = np.abs(clf.coef_[0])

# Afficher l'importance des caractéristiques
plt.figure(figsize=(10, 8))
bars = plt.barh(range(len(importance)), importance, align='center')
plt.yticks(range(len(importance)), data.columns)
plt.xlabel('Importance')
plt.title('Importance des caractéristiques - Régression Logistique')

# Ajouter les valeurs des instances sur les barres
for bar, value in zip(bars, importance):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{value:.2f}', va='center')

plt.show()

# %% [markdown]
# # SHAP (SHapley Additive explanations)

# %%
# Graphique SHAP résumé pour l'interprétabilité globale
# shap.summary_plot(shap_values, X_test)

# Créer le graphique de résumé SHAP avec les valeurs des instances
shap.summary_plot(shap_values, X_test, plot_type="dot")

# Ajouter les valeurs numériques sur les points
plt.gca().set_title('SHAP Summary Plot with Values')
for i in range(len(X_test)):
    for j in range(len(X_test.columns)):
        plt.text(shap_values[i, j], i, f'{shap_values[i, j]:.2f}', fontsize=8, ha='center')
plt.show()

# %%
# Création de l'objet explainer
explainer =shap.LinearExplainer(clf, X_train)

# Calcul des valeurs SHAP
shap_values = explainer.shap_values(X_train)

# Tracer le graphique SHAP de synthèse
shap.summary_plot(shap_values, X_train, plot_type="bar")

# Afficher le graphique
plt.show()

# %% [markdown]
# # Permutation Feature Importance
# ### Cette technique évalue l'importance d'une caractéristique en permutant les valeurs de la caractéristique et en observant l'impact sur le score du modèle.

# %%
#pip install eli5
import eli5
from eli5.sklearn import PermutationImportance

# %%
# Calculer l'importance des caractéristiques avec la permutation
perm = PermutationImportance(clf, random_state=1).fit(X_test, y_test)

# Afficher les poids
eli5.show_weights(perm, feature_names=X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2846
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
# ...

# %% [markdown]
# # Partial Dependence Plots (PDPs)
# ### Le graphique de dépendance partielle (abrégé PDP ou PD plot) montre l'effet marginal qu'une ou deux caractéristiques ont sur le résultat prédit d'un modèle d'apprentissage automatique (J. H. Friedman 200130).

# %%
from sklearn.inspection import partial_dependence, PartialDependenceDisplay 
from sklearn.datasets import load_breast_cancer

# Calculer la dépendance partielle
pdp, axes = partial_dependence(clf, X_test, features=['Fuel consumption '])

# Créer le display
display = PartialDependenceDisplay.from_estimator(
    clf,
    X_test,
    features=['Fuel consumption ']
)

# Afficher le graphique
display.plot()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\inspection\_partial_dependence.py:508: FutureWarning: A Bunch will be returned in place of 'predictions' from version 1.1 (renaming of 0.26) with partial dependence results accessible via the 'average' key. In the meantime, pass kind='average' to get the future behaviour.
#   warnings.warn(
